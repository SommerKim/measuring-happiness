# %%
import pandas as pd

# %%
csv_path = "Raw Data/human_development.csv"

# Import the books.csv file as a DataFrame
human_dev = pd.read_csv(csv_path, encoding="utf-8")
human_dev.head()
# Out:
#    HDI Rank      Country  Human Development Index (HDI)  \
# 0       1.0       Norway                          0.944
# 1       2.0    Australia                          0.935
# 2       3.0  Switzerland                          0.930
# 3       4.0      Denmark                          0.923
# 4       5.0  Netherlands                          0.922
#
#    Life Expectancy at Birth  Expected Years of Education  \
# 0                      81.6                         17.5
# 1                      82.4                         20.2
# 2                      83.0                         15.8
# 3                      80.2                         18.7
# 4                      81.6                         17.9
#
#    Mean Years of Education Gross National Income (GNI) per Capita  \
# 0                     12.6                                 64,992
# 1                     13.0                                 42,261
# 2                     12.8                                 56,431
# ...

# %%
df = pd.DataFrame(human_dev)
df
# Out:
#      HDI Rank                          Country  Human Development Index (HDI)  \
# 0         1.0                           Norway                          0.944
# 1         2.0                        Australia                          0.935
# 2         3.0                      Switzerland                          0.930
# 3         4.0                          Denmark                          0.923
# 4         5.0                      Netherlands                          0.922
# ..        ...                              ...                            ...
# 190       NaN          Europe and Central Asia                          0.748
# 191       NaN  Latin America and the Caribbean                          0.748
# 192       NaN                       South Asia                          0.607
# 193       NaN               Sub-Saharan Africa                          0.518
# 194       NaN                            World                          0.711
#
# ...

# %%
country_count = df["Country"].nunique()
country_count
# Out:
# 195

# %%
human_dev_df = df.dropna()
human_dev_df
# Out:
#      HDI Rank                   Country  Human Development Index (HDI)  \
# 0         1.0                    Norway                          0.944
# 1         2.0                 Australia                          0.935
# 2         3.0               Switzerland                          0.930
# 3         4.0                   Denmark                          0.923
# 4         5.0               Netherlands                          0.922
# ..        ...                       ...                            ...
# 183     184.0                   Burundi                          0.400
# 184     185.0                      Chad                          0.392
# 185     186.0                   Eritrea                          0.391
# 186     187.0  Central African Republic                          0.350
# 187     188.0                     Niger                          0.348
#
#      Life Expectancy at Birth  Expected Years of Education  \
# ...

# %%
human_dev_df.to_csv(r'human_dev_df.csv', index = False)
